# %% [markdown]
# ## MatplotLib Tutorial
#
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general

# %%
import matplotlib.pyplot as plt # here we are importing matplotlib.pyplot library as plt alias

# %%
# %matplotlib inline

# %%
# whenever we want to display any plot or digrams we always have to use plt.show
# But if we are using %matplotlib inline then we nedd not to write plt.show() directly we can execute the code

# %%
import numpy as np

# %%
x = np.arange(0,12)
y = np.arange(13,24) # arange is used to create an array between specified range

# %%
a = np.arange(80,90)
b = np.arange(90,100)

# %%
#plotling using matplotlib
# Scatter plot

# %%
# Scatter graph is used to scatter the value of x and y

# %%
plt.scatter(x,y, c='b')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-9b3ce245e860> in <module>
# ----> 1 plt.scatter(x,y, c='b')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4442         y = np.ma.ravel(y)
#    4443         if x.size != y.size:
# -> 4444             raise ValueError("x and y must be the same size")
#    4445
#    4446         if s is None:
#
# ValueError: x and y must be the same size

# %%
x = np.arange(0,10)
y = np.arange(11,21)

# %%
plt.scatter(x,y, c='b')

# %%
# if we haven't written %matplotlib.inline then we have write the plt.show()

# %%
## Now we have to write some title . label of x , label of y

# %%
plt.scatter(x,y, c='b')
plt.xlabel('x value')
plt.ylabel('Y label')
plt.title('sample example')
# Out:
# Text(0.5, 1.0, 'sample example')

# %%
# we can also save that graph

# %%
plt.scatter(x,y, c='b')
plt.xlabel('x value')
plt.ylabel('Y label')
plt.title('sample example')
plt.savefig('ex.jpg')

# %%
plt.plot(x,y)

# %%
y = x*x

# %%
plt.plot(x,y)

# %%
#here e can see that default color is blue

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'r--')

# %%
plt.plot(x,y,'r*')

# %%
plt.plot(x,y,'ro')

# %%
plt.plot(x,y,'ro--')

# %%
plt.plot(x,y,'r*',linestyle='dashed',linewidth=4, markersize=12)

# %%
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
# creating subplots

# %%
# sublopts= means withing one plot we are creating more than one plot

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r')

plt.subplot(2,2,2)
plt.plot(x,y,'b')

plt.subplot(2,2,3)
plt.plot(x,y,'g')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')

plt.subplot(2,2,2)
plt.plot(x,y,'b*--')

plt.subplot(2,2,3)
plt.plot(x,y,'go')

plt.subplot(2,2,4)
plt.plot(x,y,'bo')  ## here 2,2 means rows and columns and 1,2,3,4 is index number

# %%
x = np.arange(1,11) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
x = np.arange(1,11) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y)

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %%
## Bar plot

x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 

plt.bar(x, y) 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %%
# histogram

# %%
# histogram helps to find out w.r.t numbers what is the density or count on y-axis

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a) 
plt.title("histogram") 
plt.show()

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a, bins=20) 
plt.title("histogram") 
plt.show()

# %%
# boxplot

# %%
# Boxplot is used to find percentile and outliers

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=False);

# %%
data
# Out:
# [array([-0.11546654, -0.75325581,  0.39339613, -0.07635117,  0.55636612,
#          0.57933425,  0.25682301,  0.10763097,  1.62752537, -0.34203207,
#         -1.65238837, -1.41565765, -1.24249721,  0.83902382, -0.27638343,
#          0.16971514,  1.52803796, -0.28968839, -1.72740167,  0.00400948,
#         -0.23768007,  0.80882217, -1.18647471,  0.18066197,  0.89691239,
#         -1.73288423,  0.96279754,  0.63261339,  1.48086773,  0.3057647 ,
#          1.07797901, -1.366324  , -1.10146821,  0.70158657, -1.2350088 ,
#          2.01777104,  0.53994847, -0.23933849,  1.19050211, -0.69930097,
#          0.09990775, -0.31254888, -0.83593286,  1.83533848,  0.07642471,
#          0.7470302 , -0.1232486 , -0.44770369,  0.66021021,  1.05222154,
#          0.09607458,  0.87874321, -0.29542449,  0.73007371,  1.09002894,
#          0.85744495,  0.00272397, -0.11152575,  0.35449335, -0.70551572,
#          1.68856504, -0.35185959, -1.38109605, -1.25715985, -0.10610854,
#         -0.678104  ,  0.4980845 ,  0.60595855, -0.71754435,  0.85050481,
#         -0.02410966, -0.82478784,  0.2454263 , -0.32847445, -0.23092603,
#         -0.43154333,  1.81299852, -0.21393106, -1.34528916, -0.10345556,
#          1.50877592,  1.69268131,  0.32737634,  0.92333983,  1.15836006,
#         -0.9414688 ,  0.31848947, -1.21801933, -0.19761298,  0.33928596,
#         -0.86808421,  1.35390736,  1.28902553,  0.31013584, -1.07960786,
#         -0.8140606 ,  0.03109206,  0.12449885,  0.68399598, -0.27151195]),
