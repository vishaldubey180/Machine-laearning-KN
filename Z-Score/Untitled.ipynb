# %% [markdown]
# # Z score

# %%
# Let us see first what is normal n gaussian distribution

# %%
#in Normal Distribution or Gaussian Distribution we basically have bell curve
# the central limit is mean
# if we go one std deviation to right then we have mean+st deviation(σ)
# if we go one more std deviation to right then we have mean+ 2 st deviation(2σ)
#And
# if we go one std deviation to left then we have mean - st deviation(σ)
# if we go one more std deviation to left then we have mean - 2 st deviation(2σ)

# %% [markdown]
# ### If we have to convert normal distribution to standard normal distribution

# %%
# in standar normal distribution(STD) mean is zero and standard deviation is 1
# if we go right from mean then value will be 1,2,3
# if we go left from mean the value will be -1,-2,-3,

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# In normal disribution
# within the first standard deviation there 68% of the data
# within the second standard deviation there 95% of the data

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ##### To convert Normal distribution into Standard distribution

# %% [markdown]
# we use Z-score method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# BY Using above formula we can convert the normal distribution into standard distribution where mean will be 0 and std deviation will be 1

# %% [markdown]
# # z score standardization
#
# This technique consists of subtracting the mean of the column from each value in a column, and then dividing the result by the standard deviation of the column. The formula to achieve this is the following:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The result of standardization is that the features will be rescaled so that they’ll have the properties of a standard normal distribution, as follows:
#
# - μ=0
#
# - σ=1

# %% [markdown]
# μ is the mean and σ is the standard deviation from the mean.
#
# In summary, the z score (also called the standard score) represents the number of standard deviations with which the value of an observation point or data differ than the mean value of what is observed ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# In Machine Learning, feature scaling is very important and a dime a dozen because it makes sure that the features of the data-set are measured on the same scale. The concept of feature scaling has come to the fore from statistics. It is an approach to plonk different variables on the same scale. It is commonly used when data-set has varying scales. Sometimes the features of data-set use to have exhaustive and large differences between their ranges. So, in this case, standardization overawes on the data-set to bring all on the same scale.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The concept of Standardization (Z-Score Normalization) is completely based on the mathematical concepts called Standard Derivation and Variance.

# %% [markdown]
# ## Variance
# The variance is the average of the squared difference from the mean.
#
# Below are steps to derive variance:
#
# - Calculate the mean
# - Subtract the value of mean from each number
# - Square the subtracted result

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Standard Deviation
# Standard Deviation is the square root of variance.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Standardization (Z-Score Normalization)
#
# Standardization is the concept and step of putting different variables on the same scale. This concept allows comparing scores between different types of variables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# EX: a = {1,2,3,4,5}

# %%
# here mean is 3

# %%
# let's say we computed std deviation as 1

# %%
# Z score for 1 = 1-3/1=-2
# Z score for 2 = 2-3/1=-1
# Z score for 3 = 3-3/1=0
# Z score for 1 = 4-3/1=1
# Z score for 1 = 5-3/1=2

# %%
# so if we want to find out distribution of 1.5 away from the mean then we can find out easily

# %% [markdown]
# ![image.png](attachment:image.png)
